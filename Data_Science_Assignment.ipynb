# %% [markdown]
# # Data Science Tools and Examples

# %% [markdown]
# ## Introduction
# This notebook provides an overview of common data science tools, languages, and libraries. It also includes examples of basic arithmetic operations and conversions.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool        | Category          |
# |-------------|-------------------|
# | Jupyter     | Notebook          |
# | RStudio     | IDE               |
# | Apache Spark| Big Data          |
# | TensorFlow  | Machine Learning  |
# | Tableau     | Visualization     |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Below are examples of simple arithmetic operations such as addition and multiplication.

# %%
# Multiply and add numbers
a = 5
b = 10
result = (a * b) + 20
print("Result:", result)

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - Identify common libraries and tools
# - Demonstrate basic arithmetic operations
# - Convert units using Python code

# %% [markdown]
# ## Author
# Manthan Virendrakumar Jani
